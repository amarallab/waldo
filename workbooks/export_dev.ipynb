# %% [markdown]
# # export dev

# %% [raw]
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from __future__ import division
import os
import six
import pathcustomize, about
about.about()

import pickle

import math
import pandas as pd
import scipy.interpolate as interpolate
import scipy.signal as ss


import waldo
from waldo import wio
from waldo import viz
import waldo.metrics.report_card as report_card
#from waldo.metrics.report_card import compound_bl_filter
# Out:
# Python 2.7.6 (default, Mar 22 2014 22:59:56) [GCC 4.8.2] on linux2, Host: cody

# %%
STOCK_METHODS = [
    'boxcar', 'triang', 'blackman', 'hamming', 'hann', 'bartlett',
    'flattop', 'parzen', 'bohman', 'blackmanharris', 'nuttall', 'barthann',
    'kaiser', 'gaussian', 'general_gaussian', 'slepian', 'chebwin'
]

def smooth(method, series, winlen, *params):

    try:
        winlen = int(winlen) // 2 * 2 + 1 # make it odd, rounding up
        half_win = winlen // 2
        wintype = (method,) + tuple(int(x) for x in params)
        fir_win = ss.get_window(wintype, winlen)
    except ValueError:
        raise ValueError('Unrecognized smoothing type')

    b = fir_win / sum(fir_win)
    a = [1]
    #zi = ss.lfiltic(b, a)
    #zi = series[0] * np.ones(len(b) - 1)
    return ss.lfilter(b, a, series)[winlen-1:]

def one_second_timesteps(t):
    #print t[0]
    t0 = math.ceil(t[0])
    tN = math.floor(t[-1])
    return np.arange(t0, tN)

def interpolate_to_1s(t, x):
    eq_times = one_second_timesteps(t) #(t[0], t[-1], dt=dt, ndigits=0)
    interp_x = interpolate.interp1d(t, x, kind='linear')
    x_interp = interp_x(eq_times)
    return eq_times, x_interp

def get_speed(t, x, y):
    dt = np.diff(t)
    dx = np.diff(x)
    dy = np.diff(y)
    #print len(dt), len(dx), len(dy)
    dist = np.sqrt(dx**2 + dy**2)
    s = dist/dt
    return s

def clean_speed(t, x, y):
    t = np.array(t)
    x = np.array(x)
    y = np.array(y)
    xs = smooth('boxcar', x, 10)
    ys = smooth('boxcar', y, 10)
    #print 'smoothed', len(xs), len(ys)
    ti, xi = interpolate_to_1s(t, x)
    ti, yi = interpolate_to_1s(t, y)
    #print 'interp', len(ti), len(xi), len(yi)
    s2 = get_speed(ti, xi, yi)
    #print 'speeds', len(s2)
    return ti[1:], s2

# %%
#ex_id = '20130318_131111'
#ex_id = '20130614_120518'
ex_id = '20130702_135704'
experiment = wio.Experiment(experiment_id=ex_id)
graph = experiment.graph.copy()

waldo.collider.remove_nodes_outside_roi(graph, experiment)
waldo.collider.remove_blank_nodes(graph, experiment)


moving = graph.compound_bl_filter(experiment, threshold=0.5)
print len(moving), 'moving'
# Out:
# 530 moving

# %%
#p = './../data/chore/{eid}/graph.pickle'.format(eid=ex_id)
#print os.path.abspath(p)
#graph2 = pickle.load(open(p, 'r'))
graph2, rc = report_card.collision_iteration2(experiment, graph.copy())
# Out:
# Iteration 1
# Validation pass
# collisions from bbox
# 	325 suspects. trying 0 again
# Failed to find node data
# 	1 suspects. trying 1 again
# Failed to find node data
# Validation pass
# Collapse Group
# Validation pass
# Remove Single Descendents
# Validation pass
# Remove Fission-Fusion
# Validation pass
# Remove Fission-Fusion (relative)
# Validation pass
# Remove Offshoots
# Validation pass
# Remove Single Descendents
# Validation pass
# Patch Gaps
# 	228 resolved 70%
# 	1 missing data 0%
# 	0 missing data, no overlap 0%
# 	96 full data, no  overlap 29%
# 259
# Validation pass
#  short gaps
# 123 standard gaps
# 0 long gaps
# 0
# Validation pass
# Iteration 2
# Validation pass
#  short gaps
# 0 standard gaps
# 0 long gaps
# collisions from bbox
# 	96 suspects. trying 0 again
# Failed to find node data
# 	1 suspects. trying 1 again
# Failed to find node data
# Validation pass
# Collapse Group
# Validation pass
# Remove Single Descendents
# Validation pass
# Remove Fission-Fusion
# Validation pass
# Remove Fission-Fusion (relative)
# Validation pass
# Remove Offshoots
# Validation pass
# Remove Single Descendents
# Validation pass
# Patch Gaps
# 	86 resolved 89%
# 	1 missing data 1%
# 	0 missing data, no overlap 0%
# 	9 full data, no  overlap 9%
# 0
# Validation pass
#  short gaps
# 2 standard gaps
# 0 long gaps
# 0
# Validation pass
# Iteration 3
# Validation pass
#  short gaps
# 0 standard gaps
# 0 long gaps
# collisions from bbox
# 	16 suspects. trying 0 again
# Failed to find node data
# 	1 suspects. trying 1 again
# Failed to find node data
# Validation pass
# Collapse Group
# Validation pass
# Remove Single Descendents
# Validation pass
# Remove Fission-Fusion
# Validation pass
# Remove Fission-Fusion (relative)
# Validation pass
# Remove Offshoots
# Validation pass
# Remove Single Descendents
# Validation pass
# Patch Gaps
# 	6 resolved 37%
# 	1 missing data 6%
# 	0 missing data, no overlap 0%
# 	9 full data, no  overlap 56%
# 0
# Validation pass
#  short gaps
# 0 standard gaps
# 0 long gaps
# 0
# Validation pass
# Iteration 4
# Validation pass
#  short gaps
# 0 standard gaps
# 0 long gaps
# collisions from bbox
# 	11 suspects. trying 0 again
# Failed to find node data
# 	1 suspects. trying 1 again
# Failed to find node data
# Validation pass
# Collapse Group
# Validation pass
# Remove Single Descendents
# Validation pass
# Remove Fission-Fusion
# Validation pass
# Remove Fission-Fusion (relative)
# Validation pass
# Remove Offshoots
# Validation pass
# Remove Single Descendents
# Validation pass
# Patch Gaps
# 	1 resolved 9%
# 	1 missing data 9%
# 	0 missing data, no overlap 0%
# 	9 full data, no  overlap 81%
# 0
# Validation pass
#  short gaps
# 0 standard gaps
# 0 long gaps
# 0
# Validation pass
# Iteration 5
# Validation pass
#  short gaps
# 0 standard gaps
# 0 long gaps
# collisions from bbox
# 	10 suspects. trying 0 again
# Failed to find node data
# 	0 resolved 0%
# Validation pass
# Collapse Group
# Validation pass
# Remove Single Descendents
# Validation pass
# Remove Fission-Fusion
# Validation pass
# Remove Fission-Fusion (relative)
# Validation pass
# Remove Offshoots
# Validation pass
# Remove Single Descendents
# Validation pass
# Patch Gaps
# 	1 missing data 10%
# 	0 missing data, no overlap 0%
# 	9 full data, no  overlap 90%
# 0
# Validation pass
#  short gaps
# 0 standard gaps
# 0 long gaps
# 0
# Validation pass
# No change since last iteration, halting
#  short gaps
# 0 standard gaps
# 0 long gaps
#                     step  total-nodes  isolated-nodes  duration-med  \
# 0                    raw         6113             501          0.00
# 1                    roi         6113             501          0.00
# 2                  blank         6050             440          0.00
# 3                 iter 0         6050             440          0.00
# 4       collisions (228)         5822             440          0.00
# 5               simplify          902             465         12.78
# 6   gaps w/missing (382)          902              72         12.78
# 7               gaps (0)          902              72         12.78
# 8                 iter 1          902              72         12.78
# 9        collisions (86)          816              72         13.53
# 10              simplify          357             160         70.93
# 11    gaps w/missing (2)          357             156         70.93
# 12              gaps (0)          357             156         70.93
# 13                iter 2          357             156         70.93
# 14        collisions (6)          351             156         70.13
# 15              simplify          337             164         68.03
# 16    gaps w/missing (0)          337             164         68.03
# 17              gaps (0)          337             164         68.03
# 18                iter 3          337             164         68.03
# 19        collisions (1)          336             164         69.08
# 20              simplify          334             164         65.77
# 21    gaps w/missing (0)          334             164         65.77
# 22              gaps (0)          334             164         65.77
# 23                iter 4          334             164         65.77
# 24        collisions (0)          334             164         65.77
# 25              simplify          334             164         65.77
# 26    gaps w/missing (0)          334             164         65.77
# 27              gaps (0)          334             164         65.77
#
#     moving-nodes
# 0            246
# 1            246
# 2            246
# 3            246
# 4            246
# 5            235
# 6            235
# 7            235
# 8            235
# 9            235
# 10           172
# 11           172
# 12           172
# 13           172
# 14           172
# 15           169
# 16           169
# 17           169
# 18           169
# 19           169
# 20           167
# 21           167
# 22           167
# 23           167
# 24           167
# 25           167
# 26           167
# 27           167
#
# [28 rows x 5 columns]
#                     step  total-nodes  >10min  >20min  >30min  >40min  >50min
# 0                    raw         6113      70      28      12       5       1
# 1                    roi         6113      70      28      12       5       1
# 2                  blank         6050      70      28      12       5       1
# 3                 iter 0         6050      70      28      12       5       1
# 4       collisions (228)         5822      70      28      12       5       1
# 5               simplify          902      70      35      15       6       2
# 6   gaps w/missing (382)          902      70      35      15       6       2
# 7               gaps (0)          902      70      35      15       6       2
# 8                 iter 1          902      70      35      15       6       2
# 9        collisions (86)          816      70      35      15       6       2
# 10              simplify          357      71      47      29      20      12
# 11    gaps w/missing (2)          357      71      47      29      20      12
# 12              gaps (0)          357      71      47      29      20      12
# 13                iter 2          357      71      47      29      20      12
# 14        collisions (6)          351      71      47      29      20      12
# 15              simplify          337      70      49      31      23      13
# 16    gaps w/missing (0)          337      70      49      31      23      13
# 17              gaps (0)          337      70      49      31      23      13
# 18                iter 3          337      70      49      31      23      13
# 19        collisions (1)          336      70      49      31      23      13
# 20              simplify          334      69      50      31      23      13
# 21    gaps w/missing (0)          334      69      50      31      23      13
# 22              gaps (0)          334      69      50      31      23      13
# 23                iter 4          334      69      50      31      23      13
# 24        collisions (0)          334      69      50      31      23      13
# 25              simplify          334      69      50      31      23      13
# 26    gaps w/missing (0)          334      69      50      31      23      13
# 27              gaps (0)          334      69      50      31      23      13
#
# [28 rows x 7 columns]
#                     step      wm_0min    wm_10min    wm_20min    wm_30min  \
# 0                    raw  1149.175117  599.368517  385.022733  237.756700
# 1                    roi  1149.175117  599.368517  385.022733  237.756700
# 2                  blank  1149.175117  599.368517  385.022733  237.756700
# 3                 iter 0  1149.175117  599.368517  385.022733  237.756700
# 4       collisions (228)  1125.652350  599.368517  385.022733  237.756700
# 5               simplify   966.343617  521.231417  479.204550  298.530333
# 6   gaps w/missing (382)   966.343617  521.231417  479.204550  298.530333
# 7               gaps (0)   966.343617  521.231417  479.204550  298.530333
# 8                 iter 1   966.343617  521.231417  479.204550  298.530333
# 9        collisions (86)   910.145317  521.231417  479.204550  298.530333
# 10              simplify   490.806083  325.799767  465.840017  302.862400
# 11    gaps w/missing (2)   490.806083  325.799767  465.840017  302.862400
# 12              gaps (0)   490.806083  325.799767  465.840017  302.862400
# 13                iter 2   490.806083  325.799767  465.840017  302.862400
# 14        collisions (6)   472.748417  325.799767  465.840017  302.862400
# 15              simplify   438.698250  285.420250  452.860983  272.158683
# 16    gaps w/missing (0)   438.698250  285.420250  452.860983  272.158683
# 17              gaps (0)   438.698250  285.420250  452.860983  272.158683
# 18                iter 3   438.698250  285.420250  452.860983  272.158683
# 19        collisions (1)   438.573233  285.420250  452.860983  272.158683
# 20              simplify   438.699867  258.334350  480.073517  272.158683
# 21    gaps w/missing (0)   438.699867  258.334350  480.073517  272.158683
# 22              gaps (0)   438.699867  258.334350  480.073517  272.158683
# 23                iter 4   438.699867  258.334350  480.073517  272.158683
# 24        collisions (0)   438.699867  258.334350  480.073517  272.158683
# 25              simplify   438.699867  258.334350  480.073517  272.158683
# 26    gaps w/missing (0)   438.699867  258.334350  480.073517  272.158683
# 27              gaps (0)   438.699867  258.334350  480.073517  272.158683
#
#       wm_40min    wm_50min
# 0   183.308967   55.208983
# 1   183.308967   55.208983
# 2   183.308967   55.208983
# 3   183.308967   55.208983
# 4   183.308967   55.208983
# 5   176.218233  114.381350
# 6   176.218233  114.381350
# 7   176.218233  114.381350
# 8   176.218233  114.381350
# 9   176.218233  114.381350
# 10  349.629133  696.777783
# 11  349.629133  696.777783
# 12  349.629133  696.777783
# 13  349.629133  696.777783
# 14  349.629133  696.777783
# 15  443.194167  757.764567
# 16  443.194167  757.764567
# 17  443.194167  757.764567
# 18  443.194167  757.764567
# 19  443.194167  757.764567
# 20  443.194167  757.764567
# 21  443.194167  757.764567
# 22  443.194167  757.764567
# 23  443.194167  757.764567
# 24  443.194167  757.764567
# 25  443.194167  757.764567
# 26  443.194167  757.764567
# 27  443.194167  757.764567
#
# [28 rows x 7 columns]
# 84788
#  blobs have terminal data
# 334 nodes in graph
# 330 overlap
# 200 have more than 1 blob id in them
# /home/visitors/peterwinter/.pyenv/versions/general/local/lib/python2.7/site-packages/pandas/core/frame.py:2175: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   **kwargs)

# %%
moving2 = graph2.compound_bl_filter(experiment, threshold=0.5)
print len(moving2), 'moving'
# Out:
# 361 moving

# %%
def rc_duration_hist(rc):
    rc = rc.copy()
    cols = rc.columns
    
    bins = [(int(c[1:-3]), c) for c in cols if str(c[0]) == '>']

    # grab bins from column names

    bins.sort(reverse=True)
    #print bins
    
    def step_data_to_bins(step):
        # grab relevant step
        step_data = rc.iloc[step]
        #print step_data[['step', '>10min','>20min','>30min','>40min','>50min']]
        bin_data = []
        running_total = 0
        for bl, rc_label in bins:
            a = step_data[rc_label]
            n = a - running_total
            running_total += n
            #print bl, a, n
            #print 'total', running_total
            bin_data.append((bl, n))
        bin_data.sort()
        bd = {} #'step':step_name}
        for l, n in bin_data:
            bd[l] = n
        return bd
    
    bd1 = step_data_to_bins(1)
    bd2 = step_data_to_bins(-1)
    
    #bd1['step'] = 'raw'
    #bd2['step'] = 'final'
    
    df = pd.DataFrame([bd1, bd2], index=['raw', 'final'])
    df.rename(columns={10:'10-19',20:'20-29', 
                       30:'30-39',40:'40-49', 50:'50-60'}, inplace=True)
 
    ax = df.T.plot(kind='bar')
    fig = plt.figure(plt.get_fignums()[0])
    fig.set_size_inches(10, 5)
    ax.set_ylabel('number of tracks')
    ax.set_xlabel('track duration (min)')
    plt.tight_layout()

    plt.savefig('track-len-improvement.png')

rc_duration_hist(rc)

# %%
def yeild_node_data(experiment, graph):
    
    for i, (node, node_data) in enumerate(graph.nodes(data=True)):
        data = graph.consolidate_node_data(experiment=experiment, node=node)
        if data is not None and len(data):
            data.sort(inplace=True)
            consolidated_set = set(data['blob'])
            node_set = node_data.get('components', set())
            if len(node_set - consolidated_set):
                print 'WARNING! node', node, 'consolidated data is missing some components'
                #print 'in data:', consolidated_set
                #print 'in node:', node_set
                missing = node_set - consolidated_set
                print 'missing:', missing
            data.reset_index(inplace=True)
            frame0 = data.iloc[0]['frame']
            frameN = data.iloc[-1]['frame']
            df = curate_data(data)
            yield node, df
            
        elif node_data['born_f'] != node_data['born_f']:
            # only print this warning if the node lasts longer than zero frames
            print 'failed on node', node , 'frames:', node_data['born_f'], 'to', node_data['born_f']

def export_nodes(ex_id, experiment, graph, save_path):
    save_path = os.path.abspath(save_path)
    wio.file_manager.ensure_dir_exists(save_path)
    if graph is None:
        graph = self.graph.copy()  

    for node, data in yeild_node_data(experiment, graph):
        node_file = '{p}/{eid}_{bid}-node.csv'.format(p=save_path, eid=ex_id, bid=node)
        df = curate_data(data)
        df.to_csv(node_file)

    print i, 'blobs searched'
    print list(data.columns)


#save_path = './../data/clean/{eid}'.format(eid=ex_id)
#export_nodes(ex_id, experiment, graph2, save_path)

#save_path = './../data/dirty/{eid}'.format(eid=ex_id)
#export_nodes(ex_id, experiment, graph, save_path)

# %%
def summarize_graph_nodes(experiment, graph, moving, min_time=30):
    #summary_data = []
    speeds = []
    areas = []
    lifespans = []
    not_moving = 0
    too_short = 0
    for node, df in yeild_node_data(experiment, graph):
        t, x, y = df['time'], df['x'], df['y']
        t0, tN = min(t), max(t)
        life = tN - t0
        if life < min_time:
            too_short += 1
            continue
        if node not in moving:
            not_moving += 1
            continue
            
        lifespans.append(pd.DataFrame([t0, tN, life], columns=[node], index=['t0', 'tN', 'life']))
        a = df[['area']].describe()
        areas.append(a.rename(columns={'area':node}))
        
        t2, s2 =clean_speed(t, x, y)
        speeds.append(pd.DataFrame(s2, index=t2, columns=[node]).describe())

    print not_moving, 'not moving'
    print too_short, 'too short'
    lifespans = pd.concat(lifespans, axis=1).T.sort('life', ascending=False)
    areas = pd.concat(areas, axis=1).T
    speeds = pd.concat(speeds, axis=1).T
    
    return lifespans, areas, speeds

# %%
def curate_data(data):
    relevant_data = data[['frame', 'time', 'area', 'blob', 'contour_encode_len', 'contour_encoded']]
    x, y = zip(*data['centroid'])
    cx, cy = zip(*data['contour_start'])
    
    
    
    relevant_data['x'] = x
    relevant_data['y'] = y
    relevant_data['contour_start_x'] = cx
    relevant_data['contour_start_y'] = cy
    relevant_data = relevant_data[['frame', 'time','blob', 'x', 'y', 'area', 
                                   'contour_start_x','contour_start_y', 'contour_encode_len', 'contour_encoded']]
    
    duplicates_present = len(data['frame']) > len(set(data['frame']))
    if duplicates_present:
        #print 'duplicates found in', data.iloc[0]['blob']
        duplicated_frames = relevant_data[relevant_data.duplicated('frame')]['frame']
        #print len(duplicated_frames), 'frames duplicated'
        new_rows = []
        for f in duplicated_frames:
            dup = relevant_data[relevant_data['frame'] == f]
            total_area = dup['area'].sum()
            #print dup.columns
            time = dup.iloc[0]['time']
            x = np.sum(dup['x'] * dup['area']) / total_area
            y = np.sum(dup['y'] * dup['area']) / total_area
            row = {'frame':f, 
                   'time':time, 
                   'area':total_area, 
                   'x':x, 
                   'y':y, 
                   'contour_start_x':None,
                   'contour_start_y':None, 
                   'contour_encode_len':None, 
                   'contour_encoded':None}
            new_rows.append(row)
        new_rows = pd.DataFrame(new_rows)
        #print new_rows.head()
        relevant_data = pd.concat([relevant_data, new_rows])
        relevant_data.drop_duplicates('frame', take_last=True, inplace=True)
            
    relevant_data.set_index('frame', inplace=True)
    #print relevant_data.loc[duplicated_frames]
    return relevant_data

# %%
lifespans2, areas2, speeds2 = summarize_graph_nodes(experiment, graph2, moving2)
print len(lifespans2), 'nodes'
# Out:
# WARNING! node 91 consolidated data is missing some components
# missing: set([2403])
# WARNING! node
#  397 consolidated data is missing some components
# missing: set([1688, 1680, 1630])
# WARNING! node
#  8834 consolidated data is missing some components
# missing: set([8972])
# 16
#  not moving
# 131 too short
# 183 nodes

# %%
lifespans, areas, speeds = summarize_graph_nodes(experiment, graph, moving)
print len(lifespans), 'nodes'
# Out:
# 66 not moving
# 5597 too short
# 378 nodes

# %%
l = lifespans
print len(l[l['life'] > 50*60])
l = lifespans2
print len(l[l['life'] > 50*60])
# Out:
# 1
# 13

# %%
sd = lifespans
sd2 = lifespans2
col = 'life'
#col = 't0'
#col = 'tN'

low = 0 #sd[col].loc['min']
high = np.max(sd[col])
bins = np.linspace(low, high, 30)

fig, ax = plt.subplots()
ax.hist(np.array(sd[col]), bins=bins, normed=True, alpha=0.5, label='dirty')
ax.hist(np.array(sd2[col]), bins=bins, normed=True, alpha=0.5, label='clean')

print int(np.mean(sd[col])), 'mean dirty'
print int(np.mean(sd2[col])), 'mean clean'

ax.set_ylabel('frequency')
ax.set_xlabel('{c} {s}'.format(s='duration time (s)', c=col))
plt.legend()
plt.show()
# Out:
# 379 mean dirty
# 857 mean clean

# %%
sd = speeds
sd2 = speeds2
col = '50%'
col = 'min'
col = 'max'
#col = 'mean'

low = 0 #sd[col].loc['min']
high = np.max(sd[col])
bins = np.linspace(low, high, 30)

fig, ax = plt.subplots()
ax.hist(np.array(sd[col]), bins=bins, normed=True, alpha=0.5, label='dirty')
ax.hist(np.array(sd2[col]), bins=bins, normed=True, alpha=0.5, label='clean')

print int(np.mean(sd[col])), 'mean dirty'
print int(np.mean(sd2[col])), 'mean clean'

ax.set_ylabel('frequency')
ax.set_xlabel('{c} {s}'.format(s='speed', c=col))
plt.legend()
plt.show()
# Out:
# 9 mean dirty
# 11 mean clean

# %%
sd = areas
sd2 = areas2
col = '50%'
#col = 'min'
#col = 'max'
col = 'mean'

low = 0 #sd[col].loc['min']
high = np.max(sd[col])
bins = np.linspace(low, high, 30)

fig, ax = plt.subplots()
ax.hist(np.array(sd[col]), bins=bins, normed=True, alpha=0.5, label='dirty')
ax.hist(np.array(sd2[col]), bins=bins, normed=True, alpha=0.5, label='clean')

print int(np.mean(sd[col])), 'mean dirty'
print int(np.mean(sd2[col])), 'mean clean'

ax.set_ylabel('frequency')
ax.set_xlabel('{c} {s}'.format(s='area', c=col))
plt.legend()
plt.show()
# Out:
# 393 mean dirty
# 383 mean clean

# %%
lifespans2.sort('life', ascending=False).head()
# Out:
#        t0        tN      life
# 5   0.010  3600.095  3600.085
# 13  0.010  3600.095  3600.085
# 23  0.382  3600.095  3599.713
# 62  2.017  3600.095  3598.078
# 63  3.217  3600.095  3596.878
#
# [5 rows x 3 columns]

# %%
lifespans.sort('life', ascending=False).head()
# Out:
#              t0        tN      life
# 4254    287.556  3600.095  3312.539
# 10470   671.793  3600.095  2928.302
# 10477   671.889  3600.095  2928.206
# 13286  1018.564  3600.095  2581.531
# 1295    152.055  2712.620  2560.565
#
# [5 rows x 3 columns]

# %%
outfile = './../scripts/node_components.txt'
with open(outfile, 'w') as f:
    for node in lifespans2.head(25).index:
        print node
        c = list(graph2.node[node].get('components', []))
        if node not in c:
            c.append(node)
        c.sort()
        line = ','.join([str(i) for i in c]) + '\n'
        f.write(line)
# Out:
# 5
# 13
# 23
# 62
# 63
# 103
# 224
# 282
# 350
# 1295
# 4188
# 4297
# 6418
# 10470
# 10471
# 31
# 11370
# 12702
# 13798
# 22
# 14612
# 14735
# 16
# 15467
# 15898

# %%
def speed_me(node, experiment, graph):
    node_data = graph.consolidate_node_data(experiment=experiment, node=node)
    node_data.reset_index(inplace=True)
    nd = curate_data(node_data)
    t, x, y = nd['time'], nd['x'], nd['y'] 
    speed = get_speed(t, x, y)
    t2, s2 = clean_speed(np.array(t), np.array(x), np.array(y))   
    return t2, s2

# %%
node = nodes[0]

#full_t, full_s = speed_me(node, experiment, graph2)
node_data = graph2.node[node]
comps = node_data.get('components', set())
#node_data = graph2.consolidate_node_data(experiment=experiment, node=node)
#node_data.reset_index(inplace=True)
#nd = curate_data(node_data)
#t, full_s = speed_me(node, experiment, graph2)
#comps = set(nd['blob'])
full_t, full_s = speed_me(node, experiment, graph2)
speeds = [full_s]
times = [full_t]
labels = ['full']
for c in comps:
    print c
    t, s = speed_me(c, experiment, graph)
    speeds.append(s)
    times.append(t)
    labels.append(str(c))
# Out:
# 82961
# 4499
# 5
# 17366
# 83937
# 4437

# %%
## combine these different collections into a list    
data_to_plot = speeds

# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot)

ax.set_ylabel('speed pixels/s')
ax.set_xticklabels(labels)
ax.set_xlabel('track segments')
plt.show()

# %%
fig, ax = plt.subplots()
for n, t, s in zip(labels, times, speeds):
    if n == 'full':
        continue
    ax.plot(t, s, label=n, alpha=0.7)
ax.legend(loc='best')
plt.show()

# %%
def show_node(node, experiment, graph):
    print node
    node_data = graph.consolidate_node_data(experiment=experiment, node=node)
    #print node_data.head()
    node_data.reset_index(inplace=True)
    nd = curate_data(node_data)
    t, s = speed_me(node, experiment, graph2)

    fig, ax = plt.subplots()
    ax.plot(nd['x'], nd['y'], alpha=0.5)
    ax.set_ylabel('y')
    ax.set_xlabel('x')
    plt.show()

    fig, ax = plt.subplots()
    ax.plot(t, s)
    ax.set_ylabel('speed')
    ax.set_xlabel('time (s)')
    plt.show()
    
    fig, ax = plt.subplots()
    ax.plot(t, s)
    ax.set_ylabel('speed')
    ax.set_xlabel('time (s)')
    ax.set_xlim([1000, 1120])
    plt.show()

    fig, ax = plt.subplots()
    ax.plot(nd['time'], nd['area'])
    ax.set_ylabel('area')
    ax.set_xlabel('time (s)')
    plt.show()
    
print 'cleaned data'
show_node(nodes[0], experiment, graph2)
#print 'dirty data'
#show_node(nodes[0], experiment, graph)
# Out:
# cleaned data
# 5

# %%
print 'cleaned data'
show_node(nodes[1], experiment, graph2)
# Out:
# cleaned data
# 13

# %%
print 'cleaned data'
show_node(nodes[4], experiment, graph2)
# Out:
# cleaned data
# 63

# %%
#nodes = [10470, 19512, 22344, 31, 14735]
for n in nodes:
    print n
    node_data = graph2.consolidate_node_data(experiment=experiment, node=n)
    #print node_data.head()
    
    t, a = node_data['time'], node_data['area']
    
    fig, ax = plt.subplots()
    ax.plot(t, a)
    ax.set_ylabel('area')
    ax.set_xlabel('time')
    #plt.ylim([0, 15])
    plt.show()
# Out:
# 5
# 13
# 23
# 62
# 63

# %%
df = pd.DataFrame(s2, index=t2, columns=['speed'])
a = df.describe()
a

# %%
nodes = [5, 13, 23, 62, 63]
for n in nodes:
    print n
    t, s = speed_me(n, experiment, graph2)
    fig, ax = plt.subplots()
    ax.plot(t, s)
    ax.set_ylabel('speed')
    ax.set_xlabel('time')
    plt.ylim([0, 15])
    plt.show()
# Out:
# 5
# 13
# 23
# 62
# 63

# %%
df = nd[['time', 'x', 'y']]
#print len(df)
df.dropna(inplace=True, how='any')
#print len(df)
#print df.head()
t, x, y = nd['time'] , nd['x'], nd['y']
t = np.array(t)
x = np.array(x)
y = np.array(y)
#print len(t), len(x), len(y)
s_orig = get_speed(t, x, y)


#xy = zip(xs, ys)
#ti, xy_i = interpolate_to_1s(t, xy)
#xi, yi = zip(*xy_i)
#s = get_speed(ti, xi, yi)

#print len(t), len(xs)

ax.plot(t[1:], s_orig, alpha=0.5)
ax.plot(ti[1:], s2)
ax.set_ylabel('speed')
ax.set_xlabel('time')
plt.show()

# %%
def one_second_timesteps(t):
    t0 = math.ceil(t[0])
    tN = math.floor(t[-1])
    return np.arange(t0, tN)

# %%
bins = np.linspace(0, 600, 60)

fig, ax = plt.subplots()
ax.hist(np.array(life_dirty['lifespan']), bins=bins, normed=True, alpha=0.5, label='dirty')
ax.hist(np.array(life_clean['lifespan']), bins=bins, normed=True, alpha=0.5, label='clean')
ax.set_ylabel('frequency')
ax.set_xlabel('lifespan')
plt.legend()

# %%
node = 30
#print graph2.where_is(node)
data = graph2.consolidate_node_data(experiment=experiment, node=node)
data.sort(inplace=True)
if data is not None and len(data):
    data.reset_index(inplace=True)
    df = curate_data(data)

# %%
print os.path.abspath(save_path)

# %% [markdown]
# ### scratchpad

# %%
for i, (node, node_data) in enumerate(graph.nodes(data=True)):
    #print(node, node_data)
    data = graph.consolidate_node_data(experiment=experiment, node=node)
    node_file = '{p}/{eid}_{bid}-node.csv'.format(p=save_path, eid=ex_id, bid=node)
    if data is not None and len(data):
        data.reset_index(inplace=True)
        all_frames = set(data['frame'])
        if len(all_frames) < len(data['frame']):
            print 'duplicates found in', node
        df = curate_data(data)

# %%
node = 5
running_total = 0
data = []
all_data = []
for subnode in graph2.components(node):
    try:
        blob = experiment[subnode]
        df = blob.df
    except (KeyError, multiworm.MWTDataError) as e:
        print('{e} reading blob {i}'.format(e=e, i=subnode))
        continue

    if blob.empty:
        print(subnode, 'subnode of', node, 'is empty')
        continue

    df.set_index('frame', inplace=True)
    df['blob'] = subnode
    print subnode, 'has', len(df), 'frames'
    #print df['blob'].head()
    running_total += len(df)
    data.append(df)
if data:
    all_data = pd.concat(data)
    all_data.sort(inplace=True)

print
print running_total, 'running total'
print len(all_data), 'len all_data'
set(all_data['blob'])
print all_data.iloc[0].name
print all_data.iloc[-1].name
fs = list(all_data.index)
print min(fs), max(fs)
print reference[node]

# %%
#def check_consolidation(experiment, graph):
matching = []
mismatching = []
components = {}
empty = []
good_com = []
bad_com = []
reference = {}
for i, (node, node_data) in enumerate(graph2.nodes(data=True)):
    data = graph2.consolidate_node_data(experiment=experiment, node=node)
    components[node] = len(node_data.get('components', []))
    if data is not None and len(data):
        data.sort(inplace=True)
        data.reset_index(inplace=True)
        frame0 = data.iloc[0]['frame']
        frameN = data.iloc[-1]['frame']
        reference[node] = {'f0':frame0, 'born_f':node_data['born_f'], 'fN':frameN, 'died_f':node_data['died_f'],
                           'fmin':min(data['frame']), 'fmax':max(data['frame'])}
        is_matching = (frame0 == node_data['born_f']) and (frameN == node_data['died_f'])
        if is_matching:
            matching.append(node)
            good_com.append(components[node])
        else:
            mismatching.append(node)
            bad_com.append(components[node])
    else:
        empty.append(node)
        
print len(empty), 'empty nodes'
print len(matching), 'matching'
print len(mismatching), 'mismatching'
print len(good_com), len(bad_com)
print min(good_com), np.mean(good_com), max(good_com), 'good components'
print min(bad_com), np.mean(bad_com), max(bad_com), 'bad components'
#check_consolidation(experiment, graph2)
print mismatching[:4]
# Out:
# 2403 subnode of 91 is empty
# 1680
#  subnode of 397 is empty
# 1688 subnode of 397 is empty
# 1630
#  subnode of 397 is empty
# 8972
#  subnode of 8834 is empty
# 74602
#  subnode of 74602 is empty
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-16-69a4e0078a97> in <module>()
#       8 reference = {}
#       9 for i, (node, node_data) in enumerate(graph2.nodes(data=True)):
# ---> 10     data = graph2.consolidate_node_data(experiment=experiment, node=node)
#      11     components[node] = len(node_data.get('components', []))
#      12     if data is not None and len(data):
#
# /home/visitors/peterwinter/codes/waldo/code/waldo/network/graph.py in consolidate_node_data(self, experiment, node)
#     406             all_data = pd.concat(data)
#     407             all_data.sort(inplace=True)
# --> 408         return all_data
#     409
#     410     def compound_bl_filter(self, experiment, threshold):
#
# UnboundLocalError: local variable 'all_data' referenced before assignment

# %%
print 'node=', node
data = graph2.consolidate_node_data(experiment=experiment, node=node)
fs = list(data.index)
print min(fs), max(fs), 'frame to frame'
print len(data), 'rows'
print 'num components', components[node]
set(data['blob'])
graph2.node[node]
# Out:
# node= 74602
# 74602 subnode of 74602 is empty
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-22-20035396b64c> in <module>()
#       1 print 'node=', node
# ----> 2 data = graph2.consolidate_node_data(experiment=experiment, node=node)
#       3 fs = list(data.index)
#       4 print min(fs), max(fs), 'frame to frame'
#       5 print len(data), 'rows'
#
# /home/visitors/peterwinter/codes/waldo/code/waldo/network/graph.py in consolidate_node_data(self, experiment, node)
#     406             all_data = pd.concat(data)
#     407             all_data.sort(inplace=True)
# --> 408             return all_data
#     409
#     410     def compound_bl_filter(self, experiment, threshold):
#
# UnboundLocalError: local variable 'all_data' referenced before assignment
