# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from __future__ import print_function, absolute_import, unicode_literals, division
import six
from six.moves import (zip, filter, map, reduce, input, range)

import pathcustomize

import sys
import os
import pathlib
import pickle
import platform
print('Python {} ({}) [{}] on {}'.format(platform.python_version(), ', '.join(platform.python_build()), 
                                       platform.python_compiler(), sys.platform))

import matplotlib.pyplot as plt
from IPython.core.display import Image as display_image

import multiworm
import collider
import collider.viz
import wio

import numpy as np
import math
# Out:
# Python 2.7.5 (default, Mar  9 2014 22:15:05) [GCC 4.2.1 Compatible Apple LLVM 5.0 (clang-500.0.68)] on darwin

# %%
def look(graph, target, jumps, ref=False):
    subgraph = collider.subgraph.nearby(graph, target, jumps)
    temp_file = collider.viz.render_nx_as_dot(subgraph, ref=ref)
    return display_image(temp_file)

# %%
#ex_id = '20130614_120518'
#ex_id = '20130318_131111'
#ex_id = '20130414_140704'
#ex_id = '20130702_135704' # many pics
ex_id = '20130702_135652' # many pics

experiment = wio.Experiment(experiment_id=ex_id)
graph = experiment.graph.copy()

_ = collider.remove_nodes_outside_roi(graph, experiment)
candidates = collider.find_potential_cut_worms(graph, experiment)

# %%
import numpy as np

valid_count = 0
for candidate in candidates:
    try:
        outline_list = collider.get_outlines(graph, experiment, list(candidate))
        group = np.concatenate(outline_list, axis=1)
        plt.figure(figsize=(10 * len(outline_list), 10))
        plt.axis('off')
        plt.imshow(group, interpolation='none')
        plt.show()
        valid_count += 1
    except:
        pass
print("Valid count: %d" % valid_count)
# Out:
# Valid count: 0

# %%
print([graph.successors(x) for x in [70]])
# Out:
# [[72, 73]]

# %%
from datetime import datetime
import numpy as np

node = 5192     
min_duration = 1
duration_factor = 200000000000000
#xx = collider.find_time_based_collisions(graph, min_duration, duration_factor)
outlines = collider.unzip_resolve_collisions(graph, experiment, [4858], True, True)
for i, outline_list in enumerate(outlines):
    group = np.concatenate(outline_list, axis=1)
    plt.figure(figsize=(10 * len(outline_list), 10))
    plt.axis('off')
    plt.imshow(group, interpolation='none')
    plt.show()
#collider.component_size_summary(graph)
#collider.viz.direct_degree_distribution(graph, (3, 3), ignore_zero=False)
# Out:
# Removed areas: A 0, B 2
# Removed areas: A 0, B 0
# Removed areas: A 1, B 2
# Removed areas: A 0, B 4
# Removed areas: A -4, B 6
# Removed areas: A -5, B -18
# Removed areas: A 0, B -8
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A -33, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 5, B 2
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 1, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 1, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 0, B 14
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 0, B -2
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 0, B -43
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 0, B -24
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A -22, B -9
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 0, B 1
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 0, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A 0, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# Removed areas: A -4, B 0
# Removed areas: A -1, B 18
# Removed areas: A 2, B 8
# Removed areas: A -4, B 0
# Removed areas: A -11, B 23
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A 0, B 1
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -25, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -27, B 22
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -19, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -19, B 16
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -10, B 6
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -3, B 2
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -8, B 21
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -11, B 8
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A 0, B 2
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -1, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A 8, B -2
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -11, B 2
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -25, B 3
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -11, B 3
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A 4, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -14, B 1
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -8, B 6
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -3, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A 8, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -4, B 3
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A 1, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A 9, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -2, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -20, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -20, B 0
# 70, 4857 -> (4858) -> 5673, 5674, result:  [[70, 5674], [4857, 5673]]
# Removed areas: A -2, B 0
