# %% [markdown]
# # collapse_group_of_nodes Debug

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from __future__ import print_function, division
import six
import pathcustomize, about
about.about()

import wio
import collider
from collider.viz.notebook import look
# Out:
# Python 2.7.8 (default, Jul 31 2014 17:07:51) [GCC 4.8.2] on linux2, Host: liverpool

# %%
#ex_id = '20130614_120518'
#ex_id = '20130318_131111'
#ex_id = '20130414_140704'
ex_id = '20130702_135704' # many pics
#ex_id = '20130702_135652' # many pics

experiment = wio.Experiment(experiment_id=ex_id)
graph = experiment.graph.copy()
collider.remove_nodes_outside_roi(graph, experiment)
len(graph)
# Out:
# 11098

# %%
graph_mod = graph.copy()
collider.collapse_group_of_nodes(graph_mod, max_duration=5)
graph_mod.validate()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-2f022e2b9e56> in <module>()
#       1 graph_mod = graph.copy()
#       2 collider.collapse_group_of_nodes(graph_mod, max_duration=5)
# ----> 3 graph_mod.validate()
#
# /home/visitors/ntimkovich/Projects/Waldo/code/shared/collider/simplifications/graph.pyc in validate(self)
#     211             if f_delta < 1:
#     212                 raise AssertionError("Edge from {} to {} is acausal, going "
# --> 213                         "back in time {:0.0f} frames".format(a, b, -f_delta))
#     214
#     215         L.warn('Validation pass')
#
# AssertionError: Edge from 41 to 42 is acausal, going back in time 1 frames

# %%
graph_mod.node[41]['died_f'], graph_mod.node[42]['born_f']
# Out:
# (30, 29)

# %%
look(graph, 41, 2)

# %%
look(graph_mod, 41, 2)
