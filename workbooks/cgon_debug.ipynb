# %% [markdown]
# # collapse_group_of_nodes Debug

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from __future__ import print_function, division
import six
import pathcustomize, about
about.about()

import wio
import collider
from collider.viz.notebook import look
# Out:
# Python 2.7.5 (default, Mar  9 2014 22:15:05) [GCC 4.2.1 Compatible Apple LLVM 5.0 (clang-500.0.68)] on darwin, Host: cheme-87.chem-eng.northwestern.edu

# %%
#ex_id = '20130614_120518'
#ex_id = '20130318_131111'
#ex_id = '20130414_140704'
ex_id = '20130702_135704' # many pics
#ex_id = '20130702_135652' # many pics

experiment = wio.Experiment(experiment_id=ex_id)
graph = experiment.graph.copy()
collider.remove_nodes_outside_roi(graph, experiment)
len(graph)
# Out:
# 11098

# %%
graph_mod = graph.copy()
collider.collapse_group_of_nodes(graph_mod, max_duration=1, verbose=False)
graph_mod.validate()
print("Before: {bef}, After: {aft}".format(bef=len(graph.nodes()), aft=len(graph_mod.nodes())))
# Out:
# Validation pass
# Before: 11098, After: 7026

# %%
graph_mod.node[7566]['died_f'], graph_mod.node[7572]['born_f']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-5b0437a27aa1> in <module>()
# ----> 1 graph_mod.node[7566]['died_f'], graph_mod.node[7572]['born_f']
#
# KeyError: 7566

# %%
look(graph, 74602   , 4)

# %%
look(graph_mod, 7144, 4, ref=True)

# %%
graph_mod.node[6531]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-4cb2008c0760> in <module>()
# ----> 1 graph_mod.node[6531]
#
# KeyError: 6531
