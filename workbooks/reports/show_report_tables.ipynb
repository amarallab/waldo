# %% [markdown]
# # Tables Summarizing WALDO's Performance

# %% [markdown]
# This notebook is intended to show several tables that help summarize how effectivly tracks were reconstructed.
#
# These tables can only be created AFTER a recording has been corrected.

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import sys

import pandas as pd

sys.path.append('..')
import about
import pathcustomize
from waldo.conf import settings
from waldo.wio.experiment import Experiment

about.about()
# Out:
# Python 2.7.6 (default, Mar 22 2014 22:59:56) [GCC 4.8.2] on linux2, Host: cody

# %% [markdown]
# #### pick your recording

# %%
# N = 15
ex_id = '20141017_113435'
ex_id = '20141017_113439'
ex_id = '20141017_123722'
ex_id = '20141017_123725'
# N = 25
#ex_id = '20141017_134720'
#ex_id = '20141017_134724'
ex_id = '20141017_150959'
#ex_id = '20141017_151002'

#ex_id = '20130614_120518'
#ex_id = '20130318_131111'
#ex_id = '20130702_135704' # testset
#ex_id = '20130702_135652'
#ex_id = '20130414_140704'
#ex_id = '20130410_165326'
ex_id ='20130324_155127'
ex_id ='20141017_123725'
ex_id = '20141017_150959'

# %%
experiment = Experiment(experiment_id=ex_id)
original_graph = experiment.graph
graph = original_graph.copy()

# %%
print 'MWT data dir:', experiment.directory
print
print 'WALDO data dir:',  experiment.prepdata.directory
# Out:
# MWT data dir: /home/projects/worm_movement/Data/MWT_RawData/20141017_150959
#
# WALDO data dir: /home/visitors/peterwinter/codes/waldo/data/test/20141017_150959/waldo

# %%
report_card_df = experiment.prepdata.load('report-card')
a = experiment.prepdata.load('end_report')
for i in a.columns:
    print i
# Out:
# lifespan
# unknown
# split
# join
# timing
# on_edge
# outside-roi

# %% [markdown]
# # Track Counts

# %%
b = report_card_df[['phase', 'step', 'total-nodes', '>10min', '>20min', '>30min', '>40min', '>50min', 'duration-mean', 'duration-std']]
b.set_index(['phase', 'step'])
# Out:
#                                  total-nodes  >10min  >20min  >30min  >40min  \
# phase        step
# input        raw                       35021     103      48      31      20
# pre-cleaning roi                        4074      56      21      11       7
#              blank                      2738      56      21      11       7
# iter1        resolve collisions         2399      60      26      14      10
#              prune leaves               2368      60      26      14      10
#              connect_leaves              324      60      26      13      11
# iter2        resolve collisions          255      54      27      16      12
#              prune leaves                255      54      27      16      12
#              connect_leaves              252      54      27      16      12
# iter3        resolve collisions          252      54      27      16      12
#              prune leaves                252      54      27      16      12
#              connect_leaves              252      54      27      16      12
#
#                                  >50min  duration-mean  duration-std
# phase        step
# input        raw                      9           6.68         99.19
# pre-cleaning roi                      1          28.20        171.01
#              blank                    1          41.95        207.21
# iter1        resolve collisions       2          48.31        247.69
#              prune leaves             2          48.94        249.25
#              connect_leaves           4         356.75        620.30
# iter2        resolve collisions       6         455.50        798.05
#              prune leaves             6         455.50        798.05
#              connect_leaves           6         460.93        801.23
# iter3        resolve collisions       6         460.93        801.23
#              prune leaves             6         460.93        801.23
#              connect_leaves           6         460.93        801.23
#
# [12 rows x 8 columns]

# %% [markdown]
# # Network Overview

# %%
c = report_card_df[['phase', 'step', 'total-nodes', 'connected-nodes', 'isolated-nodes', 'giant-component-size', '# components']]
c.set_index(['phase', 'step'])
# Out:
#                                  total-nodes  connected-nodes  isolated-nodes  \
# phase        step
# input        raw                       35021            33148            1873
# pre-cleaning roi                        4074             2544            1530
#              blank                      2738             2539             199
# iter1        resolve collisions         2399             2162             237
#              prune leaves               2368             2127             241
#              connect_leaves              324              157             167
# iter2        resolve collisions          255               65             190
#              prune leaves                255               65             190
#              connect_leaves              252               65             187
# iter3        resolve collisions          252               65             187
#              prune leaves                252               65             187
#              connect_leaves              252               65             187
#
#                                  giant-component-size  # components
# phase        step
# input        raw                                26717          1954
# pre-cleaning roi                                 1160          1567
#              blank                               1160           234
# iter1        resolve collisions                  1160           271
#              prune leaves                        1145           271
#              connect_leaves                        25           186
# iter2        resolve collisions                    15           205
#              prune leaves                          15           205
#              connect_leaves                        15           202
# iter3        resolve collisions                    15           202
#              prune leaves                          15           202
#              connect_leaves                        15           202
#
# [12 rows x 5 columns]

# %% [markdown]
# # Track Fragmentation

# %%
def show_track_termination_report(experiment):
    df = experiment.prepdata.load('end_report')
    df['lifespan'] = ['0-1 min', '1-5 min', '6-10 min', '11-20 min', '21-60 min', 'total']
    df = df.rename(columns={'lifespan': 'track-duration', 
                            'unknown': 'disappear', 
                            'timing':'recording-finishes', 
                            'on_edge':'image-edge'})
    df.set_index('track-duration', inplace=True)
    return df

print 'Reasons for Track Termination'
print
show_track_termination_report(experiment)
# Out:
# Reasons for Track Termination
#                 disappear  split  join  recording-finishes  image-edge  \
# track-duration
# 0-1 min                15      2     3                  27          17
# 1-5 min                10      7     3                  30          14
# 6-10 min                5      0     3                  13           5
# 11-20 min               1      0     1                  17           3
# 21-60 min               2      0     1                  13           2
# total                  33      9    11                 105          41
#
#                 outside-roi
# track-duration
# 0-1 min                  11
# 1-5 min                  21
# 6-10 min                 12
# 11-20 min                 5
# 21-60 min                 4
# total                    53
#
# [6 rows x 6 columns]

# %%
def show_track_initiation_report(experiment):
    df = experiment.prepdata.load('start_report')
    df['lifespan'] = ['0-1 min', '1-5 min', '6-10 min', '11-20 min', '21-60 min', 'total']
    df = df.rename(columns={'lifespan': 'track-duration',
                            'unknown': 'appear', 
                            'timing':'recording-begins', 
                            'on_edge':'image-edge'})
    df.set_index('track-duration', inplace=True)
    return df

print 'Reasons for Track Initiation'
print
show_track_initiation_report(experiment)
# Out:
# Reasons for Track Initiation
#                 appear  split  join  recording-begins  image-edge  outside-roi
# track-duration
# 0-1 min             30      8     4                 6          19            8
# 1-5 min             25      9     4                 8          11           28
# 6-10 min            10      3     0                 1           3           21
# 11-20 min            9      3     2                 0           3           10
# 21-60 min            5      3     0                 5           2            7
# total               81     26    10                21          38           76
#
# [6 rows x 6 columns]
