# %% [markdown]
# # What's that part of the graph look like?

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from __future__ import print_function, absolute_import, unicode_literals, division
import six
from six.moves import (zip, filter, map, reduce, input, range)

import pathcustomize

import sys
import os
import pathlib
import pickle
import platform
print('Python {} ({}) [{}] on {}'.format(platform.python_version(), ', '.join(platform.python_build()), 
                                       platform.python_compiler(), sys.platform))

import matplotlib.pyplot as plt
from IPython.core.display import Image as display_image

import multiworm
import collider
import collider.viz
import wio
# Out:
# Python 2.7.5 (default, Mar  9 2014 22:15:05) [GCC 4.2.1 Compatible Apple LLVM 5.0 (clang-500.0.68)] on darwin

# %%
def look(graph, target, jumps, ref=False):
    subgraph = collider.subgraph.nearby(graph, target, jumps)
    temp_file = collider.viz.render_nx_as_dot(subgraph, ref=ref)
    return display_image(temp_file)

# %%
#ex_id = '20130614_120518'
#ex_id = '20130318_131111'
#ex_id = '20130414_140704'
#ex_id = '20130702_135704' # many pics
ex_id = '20130702_135652' # many pics

experiment = wio.Experiment(experiment_id=ex_id)
graph = experiment.graph.copy()

_ = collider.remove_nodes_outside_roi(graph, experiment)
candidates = collider.find_potential_cut_worms(graph, experiment)

# %%
import numpy as np

valid_count = 0
for candidate in candidates:
    try:
        outline_list = collider.get_outlines(graph, experiment, list(candidate))
        group = np.concatenate(outline_list, axis=1)
        plt.figure(figsize=(10 * len(outline_list), 10))
        plt.axis('off')
        plt.imshow(group, interpolation='none')
        plt.show()
        valid_count += 1
    except:
        pass
print("Valid count: %d" % valid_count)
# Out:
# Failed to find outline in 1 predeccessors
# grabbing 54 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 77 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 110 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 185 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 155 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 180 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 216 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 240 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 568 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 598 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 469 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 480 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 602 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 649 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 794 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 798 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 801 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 833 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 934 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 981 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 1876 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 1909 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2054 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2072 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2122 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2125 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2234 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2296 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2307 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2366 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2396 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2403 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2432 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2438 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2448 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 2852 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 3448 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 3560 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 3566 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 4547 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 7258 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 7270 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 7275 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 7280 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 7710 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 7716 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10393 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 9206 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 9209 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 9212 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 9798 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 9801 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10396 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10405 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10408 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10411 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10416 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10614 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10620 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10637 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10641 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10909 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10843 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10848 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10862 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10880 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10916 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10931 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10944 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 10979 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11048 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11164 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11090 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11106 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11238 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11256 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11277 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11280 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11300 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11305 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11308 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11315 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 11929 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12168 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12171 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12174 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12178 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12281 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12372 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12376 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12378 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12381 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12404 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12408 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12410 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12419 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12424 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12427 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12442 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12448 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12451 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12456 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12469 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12476 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12482 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12485 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12488 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12491 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12509 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12753 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12682 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12968 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12685 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12696 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12699 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13129 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 12899 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13172 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13176 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13178 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13181 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13184 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13189 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13194 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13208 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13214 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13246 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13249 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13257 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13264 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13282 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13288 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13290 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13307 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13314 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13329 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13341 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13345 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13348 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13356 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13368 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13371 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13374 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13377 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13384 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13387 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13400 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13402 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13414 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13426 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13429 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13432 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13438 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13444 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13456 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13459 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13474 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13478 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13481 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13484 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13490 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13494 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13502 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13612 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13677 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13708 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13712 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 13747 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14152 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14154 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14158 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14162 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14165 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14168 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14173 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14176 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14680 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14704 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14758 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14792 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14802 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14852 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14856 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14884 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14904 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14957 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14963 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14966 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14978 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14981 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 14988 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 15320 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17472 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 15972 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 15158 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 15161 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 15328 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 16034 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 16037 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 16904 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 16947 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 16950 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17267 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17485 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17493 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17572 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17576 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17580 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17584 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17597 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17602 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17605 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17626 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17632 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17802 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17805 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17820 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17838 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17841 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17860 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17901 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17872 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17875 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17878 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17896 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17899 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17905 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17912 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17926 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17940 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17968 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17971 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17974 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 17998 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18024 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18027 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18033 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18156 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18136 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18165 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18176 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18179 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18182 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18194 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18264 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18200 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18205 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18229 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18253 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18256 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18259 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18286 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18274 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18294 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18304 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18306 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18309 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18403 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18416 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18422 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18432 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18434 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18437 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18440 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18444 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18448 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18450 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18453 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18459 <type 'int'>
# Failed to find outline in 1 predeccessors
# grabbing 18496 <type 'int'>
# Valid count: 69

# %%
from datetime import datetime
import numpy as np

node = 49043     
min_duration = 1
duration_factor = 200000000000000
# xx = collider.find_potential_collisions(graph, min_duration, duration_factor)
# print ("Try unzip at %d..." % (xx[0]))
outlines = collider.unzip_resolve_collisions(graph, experiment, [node])
for i, outline_list in enumerate(outlines):
    group = np.concatenate(outline_list, axis=1)
    plt.figure(figsize=(10 * len(outline_list), 10))
    plt.axis('off')
    plt.imshow(group, interpolation='none')
    plt.show()
#collider.component_size_summary(graph)
#collider.viz.direct_degree_distribution(graph, (3, 3), ignore_zero=False)
# Out:
# Node: 49043
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-6-e617e4016aab> in <module>()
#       8 # print ("Try unzip at %d..." % (xx[0]))
#       9 outlines = collider.unzip_resolve_collisions(graph, experiment, [node])
# ---> 10 for i, outline_list in enumerate(outlines):
#      11     group = np.concatenate(outline_list, axis=1)
#      12     plt.figure(figsize=(10 * len(outline_list), 10))
#
# /Users/heltena/src/waldo/code/shared/collider/simplifications/extrinsic/collision_unzip.pyc in unzip_resolve_collisions(graph, experiment, collision_nodes)
#     237     for node in collision_nodes:
#     238         print("Node: %d" % node)
# --> 239         preds = list(set(graph.predecessors(node)))
#     240         if len(preds) != 2:
#     241             print("No preds: ", preds)
#
# /Library/Python/2.7/site-packages/networkx/classes/digraph.pyc in predecessors(self, n)
#     684     def predecessors(self, n):
#     685         """Return a list of predecessor nodes of n."""
# --> 686         return list(self.predecessors_iter(n))
#     687
#     688
#
# /Library/Python/2.7/site-packages/networkx/classes/digraph.pyc in predecessors_iter(self, n)
#     673             return iter(self.pred[n])
#     674         except KeyError:
# --> 675             raise NetworkXError("The node %s is not in the digraph."%(n,))
#     676
#     677     def successors(self, n):
#
# NetworkXError: The node 49043 is not in the digraph.

# %%
graph2 = graph.copy()
params = {
    'offshoots': 20, # default: 20
    'splits_abs': 5, # default: 5
    'splits_rel': 0.25, # default: 0.5
    'assimilate': 10, # default: 10
}
collider.removal_suite(graph2, **params)

collider.component_size_summary(graph2)
collider.viz.direct_degree_distribution(graph2, (3, 3), ignore_zero=True)

# %%
graph3 = graph2.copy()
params = {
    'offshoots': 20, # default: 20
    'splits_abs': 5, # default: 5
    'splits_rel': 0.25, # default: 0.5
    'assimilate': 10, # default: 10
}
#collider.removal_suite(graph3, **params)
#collider.remove_single_descendents(graph3)
#collider.remove_fission_fusion(graph3, 5)
collider.remove_fission_fusion_rel(graph3, 0.25)

collider.component_size_summary(graph3)
collider.viz.direct_degree_distribution(graph3, (3, 3))

# %%
set(graph) - set(graph_rerun)

# %%
look(graph, target=62981, jumps=10)

# %%
# xxx_135652
#look(graph, target=1240, jumps=15)
#look(graph, target=3399, jumps=3)
#look(graph, target=1789, jumps=2)

# %%
graph_mod = graph.copy()
collider.assimilate(graph_mod, 10)
collider.remove_single_descendents(graph_mod)
collider.component_size_summary(graph_mod)
collider.viz.direct_degree_distribution(graph_mod, (3,3), ignore_zero=True)

# %%
look(graph_mod, target=9737, jumps=5)

# %%
f, ax = collider.viz.age_distribution(original, graph, graph_mod)
ax.set_xlim([0.5, 50e3])

# %%
collider.viz.age_distribution(original)
