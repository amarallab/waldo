# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from __future__ import print_function, absolute_import, unicode_literals, division
import six
from six.moves import (zip, filter, map, reduce, input, range)

import pathcustomize

import sys
import os
import pathlib
import pickle
import platform
print('Python {} ({}) [{}] on {}'.format(platform.python_version(), ', '.join(platform.python_build()), 
                                       platform.python_compiler(), sys.platform))

import matplotlib.pyplot as plt
from IPython.core.display import Image as display_image

import multiworm
import collider
import collider.viz
import wio
# Out:
# Python 2.7.5 (default, Mar  9 2014 22:15:05) [GCC 4.2.1 Compatible Apple LLVM 5.0 (clang-500.0.68)] on darwin

# %%
def look(graph, target, jumps, ref=False):
    subgraph = collider.subgraph.nearby(graph, target, jumps)
    temp_file = collider.viz.render_nx_as_dot(subgraph, ref=ref)
    return display_image(temp_file)

# %%
#ex_id = '20130614_120518'
#ex_id = '20130318_131111'
#ex_id = '20130414_140704'
#ex_id = '20130702_135704' # many pics
ex_id = '20130702_135652' # many pics

experiment = wio.Experiment(experiment_id=ex_id)
graph = experiment.graph.copy()

_ = collider.remove_nodes_outside_roi(graph, experiment)
candidates = collider.find_potential_cut_worms(graph, experiment)

# %%
import numpy as np

valid_count = 0
for candidate in candidates:
    try:
        outline_list = collider.get_outlines(graph, experiment, list(candidate))
        group = np.concatenate(outline_list, axis=1)
        plt.figure(figsize=(10 * len(outline_list), 10))
        plt.axis('off')
        plt.imshow(group, interpolation='none')
        plt.show()
        valid_count += 1
    except:
        pass
print("Valid count: %d" % valid_count)
# Out:
# Valid count: 0

# %%
from datetime import datetime
import numpy as np

node = 5192     
min_duration = 1
duration_factor = 200000000000000
xx = collider.find_time_based_collisions(graph, min_duration, duration_factor)
outlines = collider.unzip_resolve_collisions(graph, experiment, xx, True, True)
for i, outline_list in enumerate(outlines):
    group = np.concatenate(outline_list, axis=1)
    plt.figure(figsize=(10 * len(outline_list), 10))
    plt.axis('off')
    plt.imshow(group, interpolation='none')
    plt.show()
#collider.component_size_summary(graph)
#collider.viz.direct_degree_distribution(graph, (3, 3), ignore_zero=False)
# Out:
# Node 123, No preds:  [120]
# Node 124, No preds:  [121]
# Node 140, No preds:  [9]
# Node 141, No preds:  [10]
# Node 170, No preds:
#  [141]
# Node 171, No preds:  [140]
# Node 265, No preds:
#  [170]
# Node 266, No preds:  [171]
# Node 269, No preds:  [265]
# Node 270, No preds:  [266]
# Node 379, No preds:  [99]
# Node 380, No preds:  [22]
# Node 388, No preds:  [4]
# Node 389, No preds:  [53]
# Node 447, No preds:
#  [441]
# Node 448, No preds:  [442]
# Node 452, No preds:  [447]
# Node 467, No preds:  [15]
# Node 492, No succs:  [496]
# Node 495, No preds:  [424]
# Node 496, No preds:  [492]
# Node 511, No preds:  [66]
# Node 512, No preds:  [24]
# Node 517, No preds:  [495]
# Node 570, No preds:  [298]
# Node 577, No preds:  [174]
# Node 578, No preds:  [425]
# Node 580, No preds:  [577]
# Node 581, No preds:  [578]
# Node 585, No preds:  [580]
# Node 586, No preds:  [581]
# Node 631, No preds:  [586]
# Node 632, No preds:  [585]
# Node 657, No preds:
#  [641]
# Node 661, No preds:
#  [657]
# Node 662, No preds:  [640]
# Node 678, No preds:  [661]
# Node 705, No preds:  [695]
# Node 706, No preds:  [696]
# Node 708, No preds:  [705]
# Node 743, No preds:  [708]
# Node 744, No preds:  [731]
# Node 747, No preds:  [744]
# Node 846, No preds:  [632]
# Node 865, No preds:  [856]
# Node 866, No preds:  [857]
# Node 874, No preds:  [65]
# Node 875, No preds:  [59]
# Node 877, No preds:  [874]
# Node 888, No preds:  [76]
# Node 889, No preds:  [46]
# Node 890, No preds:  [865]
# Node 892, No preds:  [31]
# Node 894, No preds:  [890]
# Node 895, No preds:  [866]
# Node 902, No preds:  [888]
# Node 903, No preds:  [889]
# Node 910, No preds:  [894]
# Node 911, No preds:  [895]
# Node 915, No preds:  [910]
# Node 916, No preds:  [911]
# Node 928, No preds:
#  [877]
# Node 949, No preds:
#  [944]
# Node 959, No preds:  [956]
# Node 960, No preds:  [957]
# Node 963, No preds:  [959]
# Node 964, No preds:  [960]
# Node 999, No preds:
#  [997]
# Node 1000, No preds:  [996]
# Node 1007, No preds:  [109]
# Node 1039, No preds:
#  [999]
# Node 1040, No preds:  [1002]
# Node 1056, No preds:  [1040]
# Node 1099, No preds:
#  [688]
# Node 1100, No preds:  [430]
# Node 1157, No preds:  [1155]
# Node 1168, No preds:  [1157]
# Node 1169, No preds:  [1154]
# Node 1208, No preds:  [1168]
# Node 1209, No preds:  [1169]
# Node 1233, No preds:  [380]
# Node 1234, No preds:  [337]
# Node 1244, No preds:  [1056]
# Node 1245, No preds:  [1001]
# Node 1354, No preds:  [1119]
# Node 1355, No preds:  [47]
# Node 1469, No succs:  [1496]
# Node 1496, No preds:  [1469]
# Node 1497, No preds:  [1496]
# Node 1498, No preds:  [1355]
# Node 1499, No preds:  [1497]
# Node 1549, No preds:  [716]
# Node 1550, No preds:  [1208]
# Node 1642, No preds:
#  [1133]
# Node 1648, No succs:  [1655]
# Node 1654, No preds:
#  [949]
# Node 1655, No preds:  [1648]
# Node 1657, No preds:  [1654]
# Node 1658, No preds:  [1655]
# Node 1662, No succs:  [1711]
# Node 1690, No succs:
#  [1701]
# Node 1692, No preds:  [1647]
# Node 1693, No preds:  [1646]
# Node 1701, No preds:  [1690]
# Node 1711, No preds:  [1662]
# Node 1712, No preds:  [1693]
# Node 1719, No preds:
#  [1711]
# Node 1720, No preds:  [1712]
# Node 1736, No succs:  [1767]
# Node 1737, No preds:  [1733]
# Node 1738, No preds:  [1719]
# Node 1766, No preds:  [1721]
# Node 1767, No preds:  [1736]
# Node 1770, No preds:  [1766]
# Node 1771, No preds:  [1767]
# Node 1811, No preds:
#  [1807]
# Node 1828, No preds:  [1824]
# Node 1839, No preds:  [1832]
# Node 1942, No preds:
#  [1937]
# Node 1943, No preds:  [1938]
# Node 1948, No preds:  [1943]
# Node 1958, No preds:  [1953]
# Node 1959, No preds:  [1954]
# Node 2008, No preds:
#  [2005]
# Node 2009, No preds:  [2006]
# Node 2025, No preds:
#  [1849]
# Node 2026, No preds:  [1311]
# Node 2028, No preds:  [2025]
# Node 2029, No preds:  [2026]
# Node 2058, No preds:  [2043]
# Node 2059, No preds:  [2044]
# Node 2065, No preds:  [2063]
# Node 2066, No preds:  [2062]
# Node 2096, No preds:
#  [1732]
# Node 2097, No preds:  [1692]
# Node 2142, No preds:  [2139]
# Node 2143, No preds:  [2140]
# Node 2145, No preds:  [2142]
# Node 2146, No preds:  [2143]
# Node 2205, No preds:
#  [1870]
# Node 2288, No preds:
#  [2285]
# Node 2289, No preds:  [2286]
# Node 2297, No preds:  [2288]
# Node 2372, No preds:
#  [2363]
# Node 2373, No preds:  [2364]
# Node 2381, No preds:  [2372]
# Node 2382, No preds:  [2373]
# Node 2416, No preds:
#  [2096]
# Node 2417, No preds:  [2205]
# Node 2466, No preds:  [2463]
# Node 2467, No preds:  [2464]
# Node 2495, No preds:
#  [2426]
# Node 2496, No preds:  [2425]
# Node 2499, No preds:  [2495]
# Node 2500, No preds:  [2496]
# Node 2551, No preds:
#  [2545]
# Node 2552, No preds:  [2546]
# Node 2560, No preds:  [2500]
# Node 2589, No preds:
#  [2585]
# Node 2590, No preds:  [2586]
# Node 2594, No preds:  [928]
# Node 2595, No preds:  [1564]
# Node 2708, No preds:
#  [2595]
# Node 2749, No preds:
#  [2728]
# Node 2750, No preds:  [2730]
# Node 2775, No preds:
#  [1498]
# Node 2800, No preds:  [2749]
# Node 2815, No preds:  [2810]
# Node 2816, No preds:  [2811]
# Node 2829, No preds:
#  [2828]
# Node 2831, No preds:  [2827]
# Node 2832, No preds:  [2829]
# Node 2871, No preds:
#  [2865]
# Node 2872, No preds:  [2866]
# Node 2894, No preds:  [2887]
# Node 2895, No preds:  [2888]
# Node 2906, No preds:  [2894]
# Node 2907, No preds:  [2895]
# Node 2912, No preds:
#  [2906]
# Node 2913, No preds:  [2907]
# Node 2950, No preds:
#  [2947]
# Node 2951, No preds:  [2948]
# Node 2953, No preds:  [2815]
# Node 2954, No preds:  [2816]
# Node 2955, No preds:  [2950]
# Node 2956, No preds:  [2951]
# Node 2970, No preds:  [2967]
# Node 2971, No preds:  [2968]
# Node 2973, No preds:  [2970]
# Node 2974, No preds:  [2971]
# Node 2977, No preds:  [2973]
# Node 2978, No preds:  [2974]
# Node 2982, No preds:  [2954]
# Node 2983, No preds:  [2953]
# Node 3007, No preds:
#  [3004]
# Node 3008, No preds:  [3005]
# Node 3320, No preds:
#  [3172]
# Node 3321, No preds:  [2560]
# Node 3323, No preds:  [3320]
# Node 3324, No preds:  [3321]
# Node 3338, No preds:  [3028]
# Node 3339, No preds:  [2800]
# Node 3386, No preds:  [1678]
# Node 3387, No preds:  [3299]
# Node 3422, No preds:
#  [3410]
# Node 3450, No preds:
#  [3323]
# Node 3534, No preds:
#  [3478]
# Node 3535, No preds:  [3443]
# Node 3553, No preds:  [3534]
# Node 3554, No preds:  [3535]
# Node 3579, No preds:
#  [3576]
# Node 3580, No preds:  [3577]
# Node 3582, No preds:  [3579]
# Node 3583, No preds:  [3580]
# Node 3586, No preds:  [3582]
# Node 3587, No preds:  [3583]
# Node 3604, No preds:  [3595]
# Node 3605, No preds:  [3596]
# Node 3608, No preds:  [3604]
# Node 3609, No preds:  [3605]
# Node 3611, No preds:  [3608]
# Node 3612, No preds:  [3609]
# Node 3614, No preds:  [3611]
# Node 3615, No preds:  [3612]
# Node 3619, No preds:  [3615]
# Node 3623, No preds:  [517]
# Node 3624, No preds:  [1734]
# Node 3670, No preds:  [3553]
# Node 3671, No preds:  [3554]
# Node 3694, No preds:
#  [3690]
# Node 3695, No preds:  [3691]
# Node 3698, No preds:  [3694]
# Node 3699, No preds:  [3695]
# Node 3701, No preds:  [3624]
# Node 3777, No preds:
#  [3670]
# Node 3778, No preds:  [3671]
# Node 3896, No preds:
#  [3890]
# Node 3897, No preds:  [3891]
# Node 3908, No preds:  [3903]
# Node 3953, No preds:  [3698]
# Node 3999, No preds:
#  [3995]
# Node 4000, No preds:  [3996]
# Node 4002, No preds:  [3999]
# Node 4003, No preds:  [4000]
# Node 4089, No preds:
#  [4086]
# Node 4090, No preds:  [4087]
# Node 4139, No preds:
#  [1920]
# Node 4229, No preds:
#  [4226]
# Node 4230, No preds:  [4227]
# Node 4431, No preds:
#  [4414]
# Node 4432, No preds:  [4415]
# Node 4459, No preds:  [4456]
# Node 4460, No preds:  [4457]
# Node 4462, No preds:  [4459]
# Node 4463, No preds:  [4460]
# Node 4504, No preds:  [4464]
# Node 4505, No preds:  [4465]
# Node 4538, No preds:
#  [4107]
# Node 4539, No preds:  [3908]
# Node 4551, No preds:  [4538]
# Node 4552, No preds:  [4539]
# Node 4556, No preds:  [4551]
# Node 4557, No preds:  [4552]
# Node 4559, No preds:  [3294]
# Node 4565, No preds:  [1819]
# Node 4566, No preds:  [4504]
# Node 4567, No preds:  [4505]
# Node 4602, No preds:
#  [4593]
# Node 4603, No preds:  [4594]
# Node 4665, No preds:  [4602]
# Node 4666, No preds:  [4603]
# Node 4702, No preds:
#  [4550]
# Node 4703, No preds:  [4139]
# Node 4754, No preds:  [3951]
# Removed areas: A 0, B 2
# Removed areas: A 0, B 0
# Removed areas: A 1, B 2
# Removed areas: A 0, B 4
# Removed areas: A -4, B 6
# Removed areas: A -5, B -18
# Removed areas: A 0, B -8
# 70, 4857 -> 5673, 5674, result:  [[70, 5673], [4857, 5674]]
# 4833, 4562 -> 4985, 4986, result:  [[4833, 4986], [4562, 4985]]
# 4478, 3559 -> 4947, 4948, result:  [[4478, 4948], [3559, 4947]]
# 4971, 4972 -> 4976, 4977, result:  [[4971, 4976], [4972, 4977]]
# 4976, 4977 -> 4987, 4988, result:  [[4976, 4987], [4977, 4988]]
# 4348, 3629 -> 5217, 5218, result:  [[4348, 5217], [3629, 5218]]
# 4394, 1238 -> 5112, 5111, result:  [[4394, 5111], [1238, 5112]]
# 3096, 4479 -> 5120, 5119, result:  [[3096, 5119], [4479, 5120]]
# 4564, 677 -> 5200, 5199, result:  [[4564, 5200], [677, 5199]]
# 5227, 5228 -> 5236, 5237, result:  [[5227, 5236], [5228, 5237]]
# 5236, 5237 -> 5248, 5247, result:  [[5236, 5247], [5237, 5248]]
# 5248, 5247 -> 5250, 5251, result:  [[5248, 5251], [5247, 5250]]
# 5250, 5251 -> 5256, 5257, result:  [[5250, 5256], [5251, 5257]]
# 4987, 4988 -> 5334, 5335, result:  [[4987, 5334], [4988, 5335]]
# 5380, 5381 -> 5451, 5452, result:  [[5380, 5451], [5381, 5452]]
# 3421, 4831 -> 5497, 5498, result:  [[3421, 5497], [4831, 5498]]
# 288, 3669 -> 5546, 5547, result:  [[288, 5547], [3669, 5546]]
# 5497, 5498 -> 5533, 5534, result:  [[5497, 5533], [5498, 5534]]
# 5558, 5559 -> 5565, 5566, result:  [[5558, 5565], [5559, 5566]]
# 5589, 5590 -> 5592, 5593, result:  [[5589, 5592], [5590, 5593]]
# 5592, 5593 -> 5837, 5838, result:  [[5592, 5837], [5593, 5838]]
# 5490, 3741 -> 5857, 5858, result:  [[5490, 5857], [3741, 5858]]
# 5837, 5838 -> 5947, 5948, result:  [[5837, 5948], [5838, 5947]]
# 5857, 5858 -> 5931, 5932, result:  [[5857, 5931], [5858, 5932]]
# 5947, 5948 -> 6026, 6027, result:  [[5947, 6027], [5948, 6026]]
# 6084, 6085 -> 6096, 6097, result:  [[6084, 6096], [6085, 6097]]
# 6096, 6097 -> 6276, 6277, result:  [[6096, 6276], [6097, 6277]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-32224a36c906> in <module>()
#       7 xx = collider.find_time_based_collisions(graph, min_duration, duration_factor)
#       8 outlines = collider.unzip_resolve_collisions(graph, experiment, xx, True, True)
# ----> 9 for i, outline_list in enumerate(outlines):
#      10     group = np.concatenate(outline_list, axis=1)
#      11     plt.figure(figsize=(10 * len(outline_list), 10))
#
# /Users/heltena/src/waldo/code/shared/collider/simplifications/extrinsic/collision_unzip.py in unzip_resolve_collisions(graph, experiment, collision_nodes, verbose, yield_bevahior)
#     143             new_b = outline_b * current_c
#     144
# --> 145             dist_a = calculate_distance_outline(new_a)
#     146             dist_b = calculate_distance_outline(new_b)
#     147
#
# /Users/heltena/src/waldo/code/shared/collider/simplifications/extrinsic/collision_unzip.py in calculate_distance_outline(outline)
#      40                     for y in [-1, 0, 1]:
#      41                         if 0 <= i + x < dist.shape[0] and \
# ---> 42                                 0 <= j + y < dist.shape[1]:
#      43                             min_value = min(min_value, dist[i + x][j + y])
#      44                 if min_value + 1 < dist[i][j]:
#
# KeyboardInterrupt:
