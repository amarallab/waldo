# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from __future__ import print_function, division
import six, sys
sys.path.append('..'); import pathcustomize, about
about.about()

import waldo
from waldo import viz
# Out:
# Python 2.7.8 (default, Jul 31 2014 17:07:51) [GCC 4.8.2] on linux2, Host: liverpool

# %%
#ex_id = '20130614_120518'
#ex_id = '20130318_131111'
#ex_id = '20130414_140704'
ex_id = '20130702_135704' # many pics
#ex_id = '20130702_135652' # many pics

experiment = waldo.Experiment(experiment_id=ex_id)
graph = experiment.graph.copy()
waldo.collider.remove_nodes_outside_roi(graph, experiment)
len(graph)
# Out:
# 11098

# %%
viz.show_gap(experiment, 22, 64)
# Out:
# Box(left=1190.5, right=1512.5, bottom=1016.5, top=1338.5)
# (<matplotlib.figure.Figure at 0x7fae40601810>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fae38fd28d0>)

# %%
for i in range(1, 2):
    f, axs = viz.show_blob(experiment, i)

# %%
from waldo.viz.tools.box import _tests as testbox
testbox()
# Out:
# Crude tests...
# OK!
