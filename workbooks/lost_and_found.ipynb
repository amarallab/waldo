# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# standard imports
import os
import sys
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import prettyplotlib as ppl
import matplotlib.gridspec as gridspec

# Path definitions
HERE = os.path.dirname(os.path.realpath('.'))
CODE_DIR = os.path.join(HERE, 'code')
SHARED_DIR = os.path.join(CODE_DIR, 'shared')

sys.path.append(CODE_DIR)
sys.path.append(SHARED_DIR)

# nonstandard imports
from wio.file_manager import get_good_blobs, get_timeseries
from metrics.measurement_switchboard import pull_blob_data

# %%
def pull_all_xy_for_ex_id(ex_id):
    """
    returns dicts containing times and xy data. keys are blob_ids.
    """
    blob_ids = get_good_blobs(ex_id=ex_id, key='xy')
    print '{N} blob_ids found'.format(N=len(blob_ids))
    blob_times, blob_xys = {}, {}
    for blob_id in blob_ids:
        times, data = get_timeseries(blob_id, data_type='xy')
        if times != None and len(times):
            blob_times[blob_id] = times
            blob_xys[blob_id] = data
    return blob_times, blob_xys

def plot_tracks(blob_xys, max_blobs=50, platesize=[1728, 2352]):
    """ quick dirty plot showing many tracks on plate. 
    
    blob_xys: (dict)
        keys are irrelivant, values are a list of xy tuples.
    max_blobs: (int)
        only plot up to this number of blobs.
    """
    fig, ax = plt.subplots()
    xmax, ymax = 0, 0
    for i, (bid, xy) in enumerate(blob_data.iteritems()):
        xy = xy[::10]
        #print len(xy)
        x, y = zip(*xy)
        ax.plot(x, y) 
        if max(x) > xmax:
            xmax = max(x)
        if max(y) > ymax:
            ymax = max(y)            
        if i > max_blobs:
            break


    #ax.set_xlim([0, platesize[0]])
    #ax.set_ylim([0, platesize[1]])
    #plt.axis('equal')
    plt.axes().set_aspect('equal', 'datalim')
    try:
        plt.show()
    except OverflowError as e:
        print 'Dataset too big to plot'
        print 'error:', e    

    
    
        
#ex_id = '20130318_131111'
ex_id = '20130614_120518'
plate_size = [1728, 2352]

blob_times, blob_xys = pull_all_xy_for_ex_id(ex_id)
plot_tracks(blob_xys, max_blobs=10)
# Out:
# 111 blob_ids found

# %%
blob_ids = sorted(blob_xys)
x0, y0 = zip(*[blob_xys[bi][0] for bi in blob_ids])
xN, yN = zip(*[blob_xys[bi][-1] for bi in blob_ids])
t0 = [blob_times[bi][0] for bi in blob_ids]
tN = [blob_times[bi][-1] for bi in blob_ids]
data = [list(i) for i in[t0, tN, x0, xN, y0, yN] ]

blobs = pd.DataFrame(data, columns=blob_ids , index=['t0', 'tN', 'x0', 'xN', 'y0', 'yN'])
blobs = blobs.T
blobs['found'] = ''
blobs['lost'] = ''
blobs.head()
# Out:
#                         t0     tN           x0           xN           y0  \
# 20130614_120518_00003  0.1  273.5   250.526869    31.517631  1307.070137
# 20130614_120518_00005  0.1  406.0   336.605197   110.641527   899.562789
# 20130614_120518_00007  0.1  198.1   383.733257   315.034729   963.596276
# 20130614_120518_00008  0.1  193.5   542.397798   799.192354   498.832948
# 20130614_120518_00018  0.1  438.8  1580.877515  1521.813970  1065.507993
#
#                                 yN found lost
# 20130614_120518_00003  1039.702327
# 20130614_120518_00005   843.136168
# 20130614_120518_00007   753.981108
# 20130614_120518_00008   915.600966
# 20130614_120518_00018  2323.962667
#
# [5 rows x 8 columns]

# %%
edge_thresh = 50
start_thresh = 30

plate_size = [1728, 2352]
xlow, xhigh = edge_thresh, plate_size[0] - edge_thresh
ylow, yhigh = edge_thresh, plate_size[1] - edge_thresh



blobs['found'][blobs['x0'] < xlow] = 'edge'
blobs['found'][blobs['y0'] < ylow] = 'edge'
blobs['found'][ xhigh < blobs['x0']] = 'edge'
blobs['found'][ yhigh < blobs['y0']] = 'edge'


blobs['lost'][blobs['xN'] < xlow] = 'edge'
blobs['lost'][blobs['yN'] < ylow] = 'edge'
blobs['lost'][ xhigh < blobs['xN']] = 'edge'
blobs['lost'][ yhigh < blobs['yN']] = 'edge'

blobs['found'][blobs['t0'] < start_thresh] = 'time'
blobs['lost'][blobs['tN'] >= 3599] = 'time'

blobs.head(20)
# Out:
#                           t0      tN           x0           xN           y0  \
# 20130614_120518_00003    0.1   273.5   250.526869    31.517631  1307.070137
# 20130614_120518_00005    0.1   406.0   336.605197   110.641527   899.562789
# 20130614_120518_00007    0.1   198.1   383.733257   315.034729   963.596276
# 20130614_120518_00008    0.1   193.5   542.397798   799.192354   498.832948
# 20130614_120518_00018    0.1   438.8  1580.877515  1521.813970  1065.507993
# 20130614_120518_00020    0.3  3600.1  1364.705207  1596.562638  1756.431507
# 20130614_120518_00162   19.0   219.1  1567.292927  1692.283056   597.701960
# 20130614_120518_00180   21.3   435.0  1179.252647  1691.675523  1333.374222
# 20130614_120518_00197   23.3   155.8   120.912775    22.771891  1376.667995
# 20130614_120518_00274   38.8   849.7   687.814189   940.608313   345.840787
# 20130614_120518_00373   55.0  1692.2  1086.690546  1274.882775  1072.019489
# 20130614_120518_00534   74.5   305.7  1082.854355   951.168983  1538.079578
# 20130614_120518_00713   93.2   284.4   378.811626   331.782061  2275.456827
# 20130614_120518_00743   99.4   288.7  1369.833046   833.727047   473.652729
# 20130614_120518_00910  119.5  2106.6   761.301966   543.923765  2133.908386
# 20130614_120518_01267  149.1   333.3  1701.876659  1693.209579   947.980442
# 20130614_120518_01497  176.6  1760.8  1125.038966   949.358937  1524.411928
# 20130614_120518_01498  176.6  1510.2  1173.676926  1011.384526  1514.323141
# 20130614_120518_01500  177.1   965.0  1425.404248  1398.493466   364.486904
# 20130614_120518_01551  193.7   406.0   798.335586   120.818647   909.677296
#
#                                 yN found  lost
# 20130614_120518_00003  1039.702327  time  edge
# 20130614_120518_00005   843.136168  time
# 20130614_120518_00007   753.981108  time
# 20130614_120518_00008   915.600966  time
# 20130614_120518_00018  2323.962667  time  edge
# 20130614_120518_00020  1739.927722  time  time
# 20130614_120518_00162   832.766467  time  edge
# 20130614_120518_00180  1845.905618  time  edge
# 20130614_120518_00197  1565.679141  time  edge
# 20130614_120518_00274   320.256374
# 20130614_120518_00373  1112.029727
# 20130614_120518_00534  1507.877074
# 20130614_120518_00713  2212.759708
# 20130614_120518_00743   979.764939
# 20130614_120518_00910  2132.147860
# 20130614_120518_01267   631.117961  edge  edge
# 20130614_120518_01497  1902.127311
# 20130614_120518_01498  1652.292007
# 20130614_120518_01500   226.866963
# 20130614_120518_01551   883.152182
#
# [20 rows x 8 columns]

# %%
def plot_exist(fig, ax, blobs, sort_col='t0', color_col='found', first=0, last=3600):
    fill_choice = {'edge':0.5, 'time':1}
    blobs = blobs.sort(sort_col)
    N_times = last - first
    N_blobs = len(blobs)
    mesh = np.zeros((N_blobs, N_times))
    for i, (bid, row) in enumerate(blobs.iterrows()):
        start, end = int(row['t0']), int(row['tN'])
        fill = fill_choice.get(row[color_col], -1)
        '''
        if row[color_col] == 'edge':
            fill = 1
        elif row[color_col] == 'time':
            fill =0.5
        else:
            fill = -1
        '''
        mesh[i][start:end] = fill
    ppl.pcolormesh(fig, ax, mesh)

print 'edge = 0.5'
print 'time = 1'
print 'unknown = -1'
    
fig, ax = subplots()     
plot_exist(fig, ax, blobs, color_col='found')
ax.set_title('found')
plt.show()

fig, ax = subplots()     
plot_exist(fig, ax, blobs, sort_col='tN', color_col='lost')
ax.set_title('lost')
plt.show()
# Out:
# edge = 0.5
# time = 1
# unknown = -1

# %%
lost = blobs.groupby('lost').size()
ax = lost.plot(kind='barh')
ax.set_xlabel('counts')
plt.show()

found = blobs.groupby('found').size()
ax = found.plot(kind='barh')
ax.set_xlabel('counts')
plt.show()
