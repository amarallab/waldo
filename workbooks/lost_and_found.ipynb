# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# standard imports
import os
import sys
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import prettyplotlib as ppl
import matplotlib.gridspec as gridspec

from __future__ import print_function, absolute_import, unicode_literals, division
import six

from six.moves import (zip, filter, map, reduce, input, range)
import pathcustomize
import itertools

'''
# Path definitions
HERE = os.path.dirname(os.path.realpath('.'))
CODE_DIR = os.path.join(HERE, 'code')
SHARED_DIR = os.path.join(CODE_DIR, 'shared')

sys.path.append(CODE_DIR)
sys.path.append(SHARED_DIR)
'''
# nonstandard imports
import multiworm
import where
import wio2
from wio.file_manager import get_good_blobs, get_timeseries
from metrics.measurement_switchboard import pull_blob_data
from importing.centroid import fill_gaps

# %%
def pull_all_xy_for_ex_id(ex_id):
    """
    returns dicts containing times and xy data. keys are blob_ids.
    """
    print(ex_id)
    blob_ids = get_good_blobs(ex_id=ex_id, key='xy_raw')

    print('{N} blob_ids found'.format(N=len(blob_ids)))
    blob_times, blob_xys = {}, {}
    for blob_id in blob_ids:
        times, data = get_timeseries(blob_id, data_type='xy_raw')
        if times != None and len(times):
            blob_times[blob_id] = times
            blob_xys[blob_id] = fill_gaps(data)
    return blob_times, blob_xys

def plot_tracks(blob_xys, max_blobs=50, platesize=[1728, 2352]):
    """ quick dirty plot showing many tracks on plate. 
    
    blob_xys: (dict)
        keys are irrelivant, values are a list of xy tuples.
    max_blobs: (int)
        only plot up to this number of blobs.
    """
    fig, ax = plt.subplots()
    xmax, ymax = 0, 0
    for i, (bid, xy) in enumerate(blob_xys.iteritems()):
        xy = xy[::10]
        #print len(xy)
        x, y = zip(*xy)
        ax.plot(x, y) 
        if max(x) > xmax:
            xmax = max(x)
        if max(y) > ymax:
            ymax = max(y)            
        if i > max_blobs:
            break


    #ax.set_xlim([0, platesize[0]])
    #ax.set_ylim([0, platesize[1]])
    #plt.axis('equal')
    plt.axes().set_aspect('equal', 'datalim')
    try:
        plt.show()
    except OverflowError as e:
        print('Dataset too big to plot')
        print('error:', e)    

    
    
        
ex_id = '20130318_131111'
#ex_id = '20130614_120518'
ex_id = '20130414_140704'
plate_size = [1728, 2352]

blob_times, blob_xys = pull_all_xy_for_ex_id(ex_id)
plot_tracks(blob_xys, max_blobs=10)
# Out:
# 20130414_140704
# 115 blob_ids found

# %%
def network_report(digraph, nodes=None, verbose=True):
    if nodes is None:
        nodes = digraph

    idig1, idig2, idig3 = itertools.tee(nodes, 3)

    loners = set()
    
    origins = set()
    fission_found = set()
    fusion_found = set()
    
    terminals = set()  
    fission_lost = set()
    fusion_lost = set()
    
    for count, node, (_, in_deg), (_, out_deg) in zip(
            itertools.count(start=1), 
            idig1, 
            dig.in_degree_iter(idig2), 
            dig.out_degree_iter(idig3)):
        
        # finding
        if in_deg == 0:
            origins.add(node)
        elif in_deg == 1:
            fission_found.add(node)
        else: # in_deg > 1
            fusion_found.add(node)

        # losing
        if out_deg == 0:
            terminals.add(node)
        elif out_deg == 1:
            fusion_lost.add(node)
        else: # out_deg > 1
            fission_lost.add(node)
      
    collision_born = fusion_found | fission_found
    collision_lost = fusion_lost | fission_lost    

    if verbose:
        print('Total blobs:       {:6d}'.format(count))
        print('collisison born:   {:6d}'.format(len(collision_born)))
        print('collision lost:    {:6d}'.format(len(collision_lost)))    
        print('0-degree blobs:    {:6d}'.format(len(origins & terminals)))

        print('-'*30)
        print('Found')        
        print('Aether-born blobs: {:6d}'.format(len(origins)))
        print('Fusion-born:       {:6d}'.format(len(fusion_found))) 
        print('Fission-born:      {:6d}'.format(len(fission_found)))
        print('Total:             {:6d}'.format(len(origins | fusion_found | fission_found))) 
        
        print('-'*30)
        print('Lost')        
        print('Abducted blobs:    {:6d}'.format(len(terminals)))
        print('Fusion-lost:       {:6d}'.format(len(fusion_lost))) 
        print('Fission-lost:      {:6d}'.format(len(fission_lost)))
        print('Total:             {:6d}'.format(len(terminals | fusion_lost | fission_lost))) 

    return collision_born, collision_lost

experiment = multiworm.Experiment(where.where(ex_id))
experiment.load_summary(graph=True)
dig = experiment.collision_graph
processed = wio2.Experiment(ex_id)
processed_ids = [worm_id for (worm_id, data) in processed.iteritems()]
print('all\n')
network_report(dig)
print('\n\nprocessed\n')
cborn, clost = network_report(dig, iter(processed_ids))
cborn = ['{eid}_{bid:0=5d}'.format(eid=ex_id, bid=i) for i in cborn]
clost = ['{eid}_{bid:0=5d}'.format(eid=ex_id, bid=i) for i in clost]
# Out:
# all
#
# Total blobs:        12543
# collisison born:     9669
# collision lost:      9412
# 0-degree blobs:      2737
# ------------------------------
# Found
# Aether-born blobs:   2874
# Fusion-born:         2972
# Fission-born:        6697
# Total:              12543
# ------------------------------
# Lost
# Abducted blobs:      3131
# Fusion-lost:         6219
# Fission-lost:        3193
# Total:              12543
#
#
# processed
#
# Total blobs:          115
# collisison born:       79
# collision lost:        79
# 0-degree blobs:        11
# ------------------------------
# Found
# Aether-born blobs:     36
# Fusion-born:            8
# Fission-born:          71
# Total:                115
# ------------------------------
# Lost
# Abducted blobs:        36
# Fusion-lost:           59
# Fission-lost:          20
# Total:                115

# %%
blob_ids = sorted(blob_xys)
x0, y0 = zip(*[blob_xys[bi][0] for bi in blob_ids])
xN, yN = zip(*[blob_xys[bi][-1] for bi in blob_ids])
t0 = [blob_times[bi][0] for bi in blob_ids]
tN = [blob_times[bi][-1] for bi in blob_ids]
data = [list(i) for i in[t0, tN, x0, xN, y0, yN] ]

blobs = pd.DataFrame(data, columns=blob_ids , index=['t0', 'tN', 'x0', 'xN', 'y0', 'yN'])
blobs = blobs.T
blobs['found'] = ''
blobs['lost'] = ''
blobs.index.name = 'bid'
bolobs.head()
# Out:
#                           t0        tN        x0        xN        y0  \
# bid
# 20130414_140704_00007  0.006   320.196   882.983   962.195  1077.439
# 20130414_140704_00016  0.606  2771.738  1251.804  1216.176  2228.938
# 20130414_140704_00017  0.606   131.649  1288.375  1087.930  1044.721
# 20130414_140704_00026  1.622   150.195   972.529  1087.547  2049.415
# 20130414_140704_00029  2.079   254.300  1615.636   477.328  2172.305
#
#                              yN found lost
# bid
# 20130414_140704_00007  1015.653
# 20130414_140704_00016  2230.510
# 20130414_140704_00017  1027.011
# 20130414_140704_00026  1825.576
# 20130414_140704_00029  1622.158
#
# [5 rows x 8 columns]

# %%
edge_thresh = 80
start_thresh = 30

plate_size = [1728, 2352]
xlow, xhigh = edge_thresh, plate_size[0] - edge_thresh
ylow, yhigh = edge_thresh, plate_size[1] - edge_thresh

blobs['found'][blobs['x0'] < xlow] = 'edge'
blobs['found'][blobs['y0'] < ylow] = 'edge'
blobs['found'][ xhigh < blobs['x0']] = 'edge'
blobs['found'][ yhigh < blobs['y0']] = 'edge'


blobs['lost'][blobs['xN'] < xlow] = 'edge'
blobs['lost'][blobs['yN'] < ylow] = 'edge'
blobs['lost'][ xhigh < blobs['xN']] = 'edge'
blobs['lost'][ yhigh < blobs['yN']] = 'edge'


blobs['found'][blobs['t0'] < start_thresh] = 'time'
blobs['lost'][blobs['tN'] >= 3599] = 'time'

for bid in clost:
    blobs.ix[bid,'lost'] = 'collision'
 
for bid in cborn:
    blobs.ix[bid, 'found'] = 'collision'

'''
for bid, row in blobs.iterrows():
    if bid in fused:
        row['lost'] = 'collision'
    if bid in fissioned:
        row['found'] = 'collision'    
'''
#print(blobs['found'][blobs['bid'] in fused])
#print(bid)
#print(blobs.loc(bid))
#blobs['lost'][] = 'collision'
#fissioned = ['{eid}_{bid:0=5d}'.format(eid=ex_id, bid=i) for i in fissioned]

blobs.head(20)
# Out:
#                             t0        tN        x0        xN        y0  \
# bid
# 20130414_140704_00007    0.006   320.196   882.983   962.195  1077.439
# 20130414_140704_00016    0.606  2771.738  1251.804  1216.176  2228.938
# 20130414_140704_00017    0.606   131.649  1288.375  1087.930  1044.721
# 20130414_140704_00026    1.622   150.195   972.529  1087.547  2049.415
# 20130414_140704_00029    2.079   254.300  1615.636   477.328  2172.305
# 20130414_140704_00044    5.557   204.023   563.571    38.266  1675.762
# 20130414_140704_00058    6.284   254.366  1206.959   510.062   664.929
# 20130414_140704_00067   11.554   200.463   996.017  1084.217  2177.023
# 20130414_140704_00156   36.253   241.690   836.491  1206.537   237.334
# 20130414_140704_00186   48.249   571.564   825.063   339.669  1683.143
# 20130414_140704_00196   50.590   241.690     9.786  1157.625   224.183
# 20130414_140704_00254   61.591   187.296  1686.944   790.758  1126.605
# 20130414_140704_00312   79.390   277.533   362.677   345.365  1820.415
# 20130414_140704_00313   80.890   308.765   459.804    30.505   477.921
# 20130414_140704_00316   81.878  1095.332   612.271  1136.517  1463.171
# 20130414_140704_00321   87.125  1000.156   491.002   866.484   434.785
# 20130414_140704_00324   87.511   403.293  1252.434  1100.238   792.166
# 20130414_140704_00441  148.801   320.196  1085.382   978.169  1021.964
# 20130414_140704_00563  190.529  2180.921   680.515   672.389    70.114
# 20130414_140704_00564  197.591   505.201   776.669  1078.771  1078.673
#
#                              yN      found       lost
# bid
# 20130414_140704_00007  1015.653       time  collision
# 20130414_140704_00016  2230.510       time  collision
# 20130414_140704_00017  1027.011       time  collision
# 20130414_140704_00026  1825.576       time  collision
# 20130414_140704_00029  1622.158       time  collision
# 20130414_140704_00044  1849.388  collision       edge
# 20130414_140704_00058  1599.345  collision  collision
# 20130414_140704_00067  2064.858  collision  collision
# 20130414_140704_00156   321.337  collision  collision
# 20130414_140704_00186  2194.073  collision
# 20130414_140704_00196   339.002       edge  collision
# 20130414_140704_00254  1031.395       edge  collision
# 20130414_140704_00312  1576.946  collision  collision
# 20130414_140704_00313   847.940  collision       edge
# 20130414_140704_00316  1051.752  collision  collision
# 20130414_140704_00321  1099.997  collision  collision
# 20130414_140704_00324   880.700             collision
# 20130414_140704_00441   971.177  collision  collision
# 20130414_140704_00563   972.980  collision  collision
# 20130414_140704_00564  1187.970  collision  collision
#
# [20 rows x 8 columns]

# %%
o

def plot_there(fig, ax, blobs, sort_col='t0',first=0, last=3600):
    blobs = blobs.sort(sort_col)
    N_times = last - first
    N_blobs = len(blobs)
    mesh = np.zeros((N_blobs, N_times))
    for i, (bid, row) in enumerate(blobs.iterrows()):
        start, end = int(row['t0']), int(row['tN'])
        mesh[i][start:end] = 1
    ppl.pcolormesh(fig, ax, mesh)    
    
print('edge = 0.5')
print('time = 1')
print('collision = -0.5')
print('unknown = -1')

fig, ax = plt.subplots()     
plot_there(fig, ax, blobs)
plt.show()  
    
fig, ax = plt.subplots()     
plot_exist(fig, ax, blobs, color_col='found')
ax.set_title('found')
plt.show()

fig, ax = plt.subplots()     
plot_exist(fig, ax, blobs, sort_col='tN', color_col='lost')
ax.set_title('lost')
plt.show()
# Out:
# edge = 0.5
# time = 1
# collision = -0.5
# unknown = -1

# %%
lost = blobs.groupby('lost').size()
ax = lost.plot(kind='barh')
ax.set_xlabel('counts')
plt.show()

found = blobs.groupby('found').size()
ax = found.plot(kind='barh')
ax.set_xlabel('counts')
plt.show()

# %%
unknown_lost = list(blobs[blobs['lost'] == ''].index)
print(len(unknown_lost), unknown_lost)
unknown_found = list(blobs[blobs['found'] == ''].index)
print(len(unknown_found), unknown_found)
# Out:
# 2 ['20130414_140704_00186', '20130414_140704_03025']
# 7 ['20130414_140704_00324', '20130414_140704_00914', '20130414_140704_01482', '20130414_140704_03163', '20130414_140704_04816', '20130414_140704_07184', '20130414_140704_11134']

# %%
ax = ((blobs['tN'] - blobs['t0']) / 60.0).hist(bins=20)
ax.set_xlabel('minutes')
plt.show()
